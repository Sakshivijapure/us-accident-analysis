# %%
#load dataset using pandas
#look at the information
#fix any missing or incorrct values

# %%
import pandas as pd
df=pd.read_csv('US_Accidents_March23.csv')
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
len(df.columns)
# Out:
# 46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
#which 5 states highest accidents
#are there more accidents in warmer  or colder area
#among the top 100 cities in number of accidents ,which state do they belong to  most frequently
#what time of the day are accidents most freq in?
#which days of the week have the most accidents?
#which  monthhs have the most accidents/
#what is the trend of accidents year over year(decreasing/increasing)
#when is accidents per unit of traffic the highest
#are there more accid ents in warmer or colder areas
#which 5 sttaes have the highest number of accidents?how about per capita?

# %%
#getting counts of only numeric col
numeric=['int16','int32','int64','float16','float32','float64']
numeric_df=df.select_dtypes(include=numeric)
len(numeric_df.columns)
# Out:
# 13

# %%
df.columns.isnull().sum()
# Out:
# np.int64(0)

# %%
missing_per=df.isna().sum().sort_values(ascending=False)/len(df)
missing_per[missing_per!=0]
# Out:
# End_Lng                  4.402935e-01
# End_Lat                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Sunrise_Sunset           3.007869e-03
# Civil_Twilight           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Nautical_Twilight        3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# dtype: float64

# %%
#remove columns that you dont need
#columns will analyz
'''1]city
   2]start time
   3]start lat,start lang
   4]temperature
   5]weather condition
   
   
'''
# Out:
# '1]city\n   2]start time\n   3]start lat,start lang\n   4]temperature\n   5]weather condition\n\n\n'

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities=df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accidens=df.City.value_counts()
cities_by_accidens
# Out:
# City
# Miami          186917
# Houston        169609
# Los Angeles    156491
# Charlotte      138652
# Dallas         130939
#                 ...
# Saint Croix         1
# Masardis            1
# Okaton              1
# Wasta               1
# Adell               1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accidens[:20].plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
import seaborn as sns 
sns.set_style("darkgrid")
sns.distplot(cities_by_accidens)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\945202869.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cities_by_accidens)
# <Axes: xlabel='count', ylabel='Density'>

# %%
#this graph shows that very high accidents between 0-2000

# %%
high_accidents_cities=cities_by_accidens[cities_by_accidens>=1000]
low_accidents_cities=cities_by_accidens[cities_by_accidens<1000]

# %%
len(high_accidents_cities)/len(cities)
# Out:
# 0.08904159660793917

# %%
sns.histplot(cities_by_accidens,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
#this graph say more than 1000 cities has 0 accidents.may be some missing data.

# %%
cities_by_accidens[cities_by_accidens==1]
# Out:
# City
# American Fork-Pleasant Grove    1
# Berlin township                 1
# District 1 Abingdon             1
# Selby                           1
# Smackover                       1
#                                ..
# Saint Croix                     1
# Masardis                        1
# Okaton                          1
# Wasta                           1
# Adell                           1
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# ###start time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 05:46:00'

# %% [markdown]
# it is currently in string .convert it to date

# %%
import pandas as pd

df['Start_Time ']= pd.to_datetime(df['Start_Time'],format='mixed')
df.Start_Time[0]
# Out:
# '2016-02-08 05:46:00'

# %%
df.dtypes
# Out:
# ID                               object
# Source                           object
# Severity                          int64
# Start_Time               datetime64[ns]
# End_Time                         object
# Start_Lat                       float64
# Start_Lng                       float64
# End_Lat                         float64
# End_Lng                         float64
# Distance(mi)                    float64
# Description                      object
# Street                           object
# City                             object
# County                           object
# State                            object
# Zipcode                          object
# Country                          object
# Timezone                         object
# Airport_Code                     object
# Weather_Timestamp                object
# Temperature(F)                  float64
# Wind_Chill(F)                   float64
# Humidity(%)                     float64
# ...

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')

# %%
df.Start_Time.dt.hour
# Out:
# 0           5.0
# 1           6.0
# 2           6.0
# 3           7.0
# 4           7.0
#            ...
# 7728389    18.0
# 7728390    19.0
# 7728391    19.0
# 7728392    19.0
# 7728393    18.0
# Name: Start_Time, Length: 7728394, dtype: float64

# %%
sns.histplot(df.Start_Time.dt.hour,bins=24,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %%
sns.histplot(df.Start_Time.dt.day_of_week,bins=7,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %%
#is the distribution of accidents by hour the same on weekends as on weekdays

# %%
sundays_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sundays_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\1612182456.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
monday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\1709319197.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\3016371076.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
df_2019=df[df.Start_Time.dt.year==2016]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\1967615980.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
df_2019=df[df.Start_Time.dt.year==2019]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\3329303641.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# much data is missing for 2016.may be even for 2017

# %%
df.Source.value_counts()
# Out:
# Source
# Source1    4325632
# Source2    3305373
# Source3      97389
# Name: count, dtype: int64

# %%
df_2019=df[df.Start_Time.dt.year==2019]
df_2019_source1=df_2019[df_2019.Source=='Source2']
sns.distplot(df_2019_source1.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# C:\Users\vijap\AppData\Local\Temp\ipykernel_9300\2926537604.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019_source1.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# there seems to be some issue with the source1 data

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# consider excluding source2 .as is seems to havve missing data

# %%
##start_lat and longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sns.scatterplot(x=df.Start_Lng,y=df.Start_Lat,size=0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>
# C:\Users\vijap\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\vijap\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from folium.plugins import HeatMap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 from folium.plugins import HeatMap
#
# ModuleNotFoundError: No module named 'folium'

# %%
#summay
'''insights
less than
more than 1000 cities have only 1 accident
high per of accidents occur between  6-10 am and 3-6 pm
on sundays ,the peak occurs between 10-3 pm

'''
